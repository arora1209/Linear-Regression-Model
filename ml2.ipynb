# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
p=pd.read_csv('newfuel.csv',encoding='unicode escape')

# %%
p.head()
# Out:
#   MODEL   MAKE                 MODEL.1 VEHICLE CLASS ENGINESIZE  CYLINDERS  \
# 0  YEAR    NaN  # = high output engine           NaN        (L)        NaN
# 1  1995  ACURA                 INTEGRA    SUBCOMPACT        1.8        4.0
# 2  1995  ACURA                 INTEGRA    SUBCOMPACT        1.8        4.0
# 3  1995  ACURA            INTEGRA GS-R    SUBCOMPACT        1.8        4.0
# 4  1995  ACURA                  LEGEND       COMPACT        3.2        6.0
#
#   TRANSMISSION  FUEL  FUELCONSUMPTION      Unnamed: 9      Unnamed: 10  \
# 0          NaN  TYPE  CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)
# 1           A4     X             10.2               7              8.8
# 2           M5     X              9.6               7              8.4
# 3           M5     Z              9.4               7              8.3
# 4           A4     Z             12.6             8.9             10.9
#
#   Unnamed: 11 CO2EMISSIONS
# 0  COMB (mpg)       (g/km)
# 1          32          202
# ...

# %%
pq=p[['ENGINESIZE','CYLINDERS','CO2EMISSIONS']]

# %%
pq
# Out:
#      ENGINESIZE  CYLINDERS CO2EMISSIONS
# 0           (L)        NaN       (g/km)
# 1           1.8        4.0          202
# 2           1.8        4.0          193
# 3           1.8        4.0          191
# 4           3.2        6.0          251
# 5           3.2        6.0          260
# 6           3.2        6.0          258
# 7             3        6.0          267
# 8             3        6.0          255
# 9             3        6.0          301
# 10            3        6.0          267
# 11          2.8        6.0          248
# 12          2.8        6.0          237
# 13          2.8        6.0          244
# 14          2.8        6.0          255
# 15          2.8        6.0          262
# 16          2.8        6.0          262
# 17          2.8        6.0          255
# 18          2.8        6.0          251
# 19          2.2        5.0          264
# 20          6.7        8.0          437
# 21          6.7        8.0          437
# ...

# %%
plt.scatter(pq.ENGINESIZE,pq.CYLINDERS)
plt.xlabel("ENGINESIZE")
plt.ylabel("CYLINDERS")
plt.show()

# %%
msk=np.random.rand(len(pq))<0.8
train=pq[msk]
test=pq[~msk]

# %%
plt.scatter(pq.ENGINESIZE,pq.CO2EMISSIONS)
plt.xlabel("ENGINESIZE")
plt.ylabel("CO2EMISSIONS")
plt.show()

# %%
from sklearn import linear_model

# %%
pq=p[['ENGINESIZE','CYLINDERS','CO2EMISSIONS','FUELCONSUMPTION']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION']])
y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-75b32029c2f6> in <module>
#       1 from sklearn import linear_model
#       2 regr = linear_model.LinearRegression()
# ----> 3 x = np.asanyarray(train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION']])
#       4 y = np.asanyarray(train[['CO2EMISSIONS']])
#       5 regr.fit (x, y)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...
